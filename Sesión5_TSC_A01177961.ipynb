# %% [markdown]
# <a href="https://colab.research.google.com/github/tanyasosa/SeriesDeTiempo_TSC_A01177961/blob/main/Sesi%C3%B3n5_TSC_A01177961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series de Tiempo
# ## Tanya Sosa Cavazos A01177961
# ### Sesión 5. 28 de Febrero 2023

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
pasajeros = pd.read_csv('https://raw.githubusercontent.com/jaime-escobedo-tec/SeriesDeTiempo-Tec/main/airline_passengers.csv',index_col='Month',parse_dates=True)

# %%
pasajeros.dropna(inplace=True)

# %%
# mostrar encabezado
pasajeros.tail()
# Out:
#             Thousands of Passengers
# Month
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432

# %%
#graficar series
pasajeros.plot(figsize=(12,6));

# %%
## result = seasonal_decompose(serie, model='mult' o 'ad')  
## result.plot()

result = seasonal_decompose(pasajeros['Thousands of Passengers'], model='mult')
result.plot();

# %%
## acceder al componente estacional
result.seasonal
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
#                 ...
# 1960-08-01    1.219911
# 1960-09-01    1.060492
# 1960-10-01    0.921757
# 1960-11-01    0.801178
# 1960-12-01    0.898824
# Name: seasonal, Length: 144, dtype: float64

# %%
pasajeros['serie_deses'] = pasajeros['Thousands of Passengers']/result.seasonal

# %%
pasajeros['serie_deses'].plot(figsize=(12,6));

# %%
pasajeros['Thousands of Passengers'].plot(figsize=(12,6));
